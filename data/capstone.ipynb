# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.ticker as mtick

# %%
ages_no_team = pd.read_excel('age_breakdown.xlsx',sheet_name='NO MLB Team')

# %%
ages_no_team.head
# Out:
# <bound method NDFrame.head of                 City  Percent of Male Pop Between 30-54 Years Old
# 0         Austin, TX                                       0.2179
# 1      Charlotte, NC                                       0.1766
# 2        El Paso, TX                                       0.1602
# 3   Indianapolis, IN                                       0.1611
# 4   Jacksonville, FL                                       0.1641
# 5     Louisville, KY                                       0.1584
# 6      Nashville, TN                                       0.1805
# 7  Oklahoma City, OK                                       0.1634
# 8       Portland, OR                                       0.2162
# 9    San Antonio, TX                                       0.1716>

# %%
cols = ['red' if y < 17 else 'grey' for in ages_no_team.Percent of Male Pop Between 30-54 Years Old]
# Out:
#   Cell In[36], line 1
#     cols = ['red' if y < 17 else 'grey' for in ages_no_team.Percent of Male Pop Between 30-54 Years Old]
#                                             ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x = "Percent of Male Pop Between 30-54 Years Old",
            y = "City",
           data = ages_no_team).axvline(x=0.1789, color= 'black', linewidth=2,)
ax.text(0.1835,4, "Avg MLB City 17.9%")
#.text(x= 0, y=9.25, s='target');
#plt.axvline(x=np.nanmean(ages_has_team.x))
ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));
# Out:
# C:\Users\toddf\AppData\Local\Temp\ipykernel_11916\1043313767.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

# %%
sns.FacetGrid(crocs2, col = 'REGION', aspect = 2, col_wrap = 2, hue = 'REGION', palette = ['green', 'grey', 'grey', 'grey', 'grey', 'grey', 'green', 'grey', 'green','grey'])

# %%
ages_has_team = pd.read_excel('age_breakdown.xlsx',sheet_name='Has MLB Team')

# %%
#ages_has_team['Percent of Male Pop Between 30-54'] = ages_has_team['Percent of Male Pop Between 30-54']*100

# %%
#ages_has_team['Percent of Male Pop Between 30-54'] = pd.Series(["{0:.2f}%".format(val * 100) for val in ages_has_team['Percent of Male Pop Between 30-54']], index = ages_has_team.index)

# %%
ages_has_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   City                                         26 non-null     object
#  1   Percent of Male Pop Between 30-54 Years Old  26 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 548.0+ bytes

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
sns.barplot(x = "Percent of Male Pop Between 30-54 Years Old",
            y = "City",
           data = ages_has_team)
#ax.xaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));
# Out:
# C:\Users\toddf\AppData\Local\Temp\ipykernel_46836\3979966706.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

# %%
education_no_team = pd.read_excel('education_breakdown.xlsx',sheet_name='NO MLB Team')

# %%
education_no_team
# Out:
#                 City  \
# 0         Austin, TX
# 1      Charlotte, NC
# 2        El Paso, TX
# 3   Indianapolis, IN
# 4   Jacksonville, FL
# 5     Louisville, KY
# 6      Nashville, TN
# 7  Oklahoma City, OK
# 8       Portland, OR
# 9    San Antonio, TX
#
#    Percent of Males at least 25 years old with at least a Bachelor's Degree
# 0                                             0.3047
# 1                                             0.2238
# 2                                             0.1292
# 3                                             0.1860
# 4                                             0.1468
# 5                                             0.1650
# 6                                             0.2293
# 7                                             0.1714
# 8                                             0.2399
# 9                                             0.1379

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x = "Percent of Males at least 25 years old with at least a Bachelor's Degree",
            y = "City",
           data = education_no_team).axvline(x=0.2139, color= 'black', linewidth=2)
ax.text(0.22,4, "Avg MLB City 21.4%")
ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));
#sns.barplot(x = "Percent of Males at least 25 years old with at least a Bachelor's Degree",
            #y = "City",
           #data = education_no_team
# Out:
# C:\Users\toddf\AppData\Local\Temp\ipykernel_11916\4157410878.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

# %%
education_has_team = pd.read_excel('education_breakdown.xlsx',sheet_name='Has MLB Team')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
sns.barplot(x = "Percent of Males at least 25 years old with at least a Bachelor's Degree",
            y = "City",
           data = education_has_team)
ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));
# Out:
# C:\Users\toddf\AppData\Local\Temp\ipykernel_46836\503180612.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

# %%
income_has_team = pd.read_excel('income_breakdown.xlsx',sheet_name='HAS MLB Team')

# %%
income_has_team
# Out:
#                  City  Percent of Households Making at Least $60K
# 0         Atlanta, GA                                      0.6212
# 1       Baltimore, MD                                      0.4618
# 2          Boston, MA                                      0.6133
# 3         Chicago, IL                                      0.5597
# 4      Cincinnati, OH                                      0.4350
# 5       Cleveland, OH                                      0.3203
# 6          Dallas, TX                                      0.5351
# 7          Denver, CO                                      0.6479
# 8         Detroit, MI                                      0.2933
# 9         Houston, TX                                      0.5037
# 10    Kansas City, MO                                      0.5168
# 11    Los Angeles, CA                                      0.5891
# 12          Miami, FL                                      0.5087
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
sns.barplot(x = "Percent of Households Making at Least $60K",
            y = "City",
           data = income_has_team)
ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));
# Out:
# C:\Users\toddf\AppData\Local\Temp\ipykernel_46836\3354213555.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

# %%
income_no_team = pd.read_excel('income_breakdown.xlsx',sheet_name='NO MLB Team')

# %%
income_no_team
# Out:
#                 City  Percent of Households Making at Least $60K
# 0         Austin, TX                                      0.6688
# 1      Charlotte, NC                                      0.5977
# 2        El Paso, TX                                      0.4438
# 3   Indianapolis, IN                                      0.5075
# 4   Jacksonville, FL                                      0.5589
# 5     Louisville, KY                                      0.5233
# 6      Nashville, TN                                      0.5796
# 7  Oklahoma City, OK                                      0.5234
# 8       Portland, OR                                      0.6230
# 9    San Antonio, TX                                      0.4911

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x = "Percent of Households Making at Least $60K",
            y = "City",
           data = income_no_team).axvline(x=0.5502, color= 'black', linewidth=2)
ax.text(0.56,3, "Avg MLB City 55%")
ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

#sns.barplot(x = "Percent of Households Making at Least $60K",
           # y = "City",
          # data = income_no_team)
# Out:
# C:\Users\toddf\AppData\Local\Temp\ipykernel_11916\2195957401.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(map('{:.1f}%'.format, 100*ax.xaxis.get_majorticklocs()));

# %%
pop_no_team = pd.read_excel('pop_breakdown.xlsx',sheet_name='NO MLB Team')

# %%
pop_no_team
# Out:
#                 City  Population
# 0         Austin, TX      974447
# 1      Charlotte, NC      897720
# 2        El Paso, TX      677456
# 3   Indianapolis, IN      880621
# 4   Jacksonville, FL      971319
# 5     Louisville, KY      624444
# 6      Nashville, TN      683622
# 7  Oklahoma City, OK      694800
# 8       Portland, OR      635067
# 9    San Antonio, TX     1472909

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x = "Population",
            y = "City",
           data = pop_no_team).axvline(x=700000, color= 'black', linewidth=2)
ax.text(730000,2, "Avg MLB City (w/o top 4 cities) 690K");
